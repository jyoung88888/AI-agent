# %%
import os 

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

if OPENAI_API_KEY is None:
    raise ValueError('OPENAI_API_KEY environment variable is not set.')

# %%
from openai import OpenAI

client = OpenAI(
    api_key=OPENAI_API_KEY
)

# %%
completion = client.chat.completions.create(
    model='gpt-4o',
    messages=[{'role': 'user', 'content': 'AI가 무엇인가요?'}],
    temperature=0.0 # 0.0 ~ 2.0 사이 값 지정 가능
)

print(completion.choices[0].message.content)
# Out:
# AI(인공지능)는 인간의 지능을 모방하거나 확장하는 컴퓨터 시스템이나 소프트웨어를 의미합니다. AI는 다양한 작업을 수행할 수 있도록 설계되었으며, 일반적으로 학습, 추론, 문제 해결, 이해 및 자연어 처리와 같은 기능을 포함합니다. AI 기술은 머신러닝, 딥러닝, 자연어 처리, 컴퓨터 비전 등 여러 분야에서 발전하고 있으며, 이러한 기술을 통해 자율주행차, 가상 비서, 추천 시스템 등 다양한 응용 프로그램이 개발되고 있습니다. AI는 데이터를 분석하고 패턴을 인식하여 스스로 학습할 수 있는 능력을 갖추고 있어, 점점 더 복잡한 문제를 해결하는 데 사용되고 있습니다.

# %%
completion = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {'role': 'system', 'content': '당신은 컴퓨터 선생님입니다. 초등학교 5학년한테 설명하듯이 아주 쉽고 친근하게 설명해주세요.'},
        {'role': 'user', 'content': 'AI가 무엇인가요?'}
    ],
    temperature=0.0
)

print(completion.choices[0].message.content)
# Out:
# 안녕! AI에 대해 궁금하구나? AI는 "인공지능"이라고도 불리는데, 쉽게 말해서 컴퓨터가 사람처럼 생각하고 배우는 능력을 가지는 거야. 예를 들어, 우리가 친구랑 대화할 때처럼 컴퓨터가 우리 말을 이해하고 대답할 수 있는 거지.
#
# AI는 여러 가지 일을 할 수 있어. 예를 들어, 스마트폰에 있는 음성 비서가 우리가 말하는 걸 듣고 날씨를 알려주거나, 게임에서 적을 똑똑하게 움직이게 하거나, 심지어는 그림을 그리거나 음악을 만드는 것도 가능해!
#
# AI는 많은 데이터를 보고 배우면서 점점 더 똑똑해져. 마치 우리가 책을 읽고 공부하면서 똑똑해지는 것처럼 말이야. 그래서 AI는 우리 생활을 더 편리하고 재미있게 만들어주는 멋진 기술이란다! 궁금한 게 더 있으면 언제든지 물어봐!

# %% [markdown]
# ## MT-Bench

# %%
question = '하늘은 왜 하늘색인가요?'

print(question)
# Out:
# 하늘은 왜 하늘색인가요?

# %%
completion = client.chat.completions.create(
    model='gpt-3.5-turbo-0125',
    messages=[{'role': 'user', 'content': question}],
    temperature=0.0
)

answer_a = completion.choices[0].message.content
print(answer_a)
# Out:
# 하늘은 일반적으로 푸른 색을 띠는데, 이는 태양 빛이 대기 중의 공기 분자들과 상호 작용하여 발생하는 현상 때문입니다. 태양 빛은 다양한 색상의 빛으로 구성되어 있지만, 대기 중의 공기 분자들은 특히 파란색 빛을 더 많이 흡수하고 반사합니다. 그래서 우리가 하늘을 바라볼 때 파란색이 더 많이 보이는 것입니다.

# %%
completion = client.chat.completions.create(
    model='gpt-4-turbo',
    messages=[{'role': 'user', 'content': question}],
    temperature=0.0
)

answer_b = completion.choices[0].message.content
print(answer_b)
# Out:
# 하늘의 색깔이 하늘색인 이유는 대기 중의 분자들과 작은 입자들이 태양 빛을 산란시키기 때문입니다. 태양에서 오는 빛은 사실 여러 색의 빛이 섞인 백색광입니다. 이 빛이 지구의 대기에 도달하면, 대기 분자들에 의해 산란되는데, 이 과정을 레일리 산란(Rayleigh scattering)이라고 합니다.
#
# 레일리 산란은 빛의 파장이 짧을수록 더 강하게 산란됩니다. 빛의 파장 중에서 파란색과 보라색은 가장 짧기 때문에 가장 강하게 산란됩니다. 그러나 인간의 눈은 보라색 빛을 파란색 빛보다 덜 감지하기 때문에, 우리는 하늘을 파란색으로 인식하게 됩니다.
#
# 태양이 지평선에 가까울 때, 즉 일출이나 일몰 때에는 하늘이 빨강, 주황, 노랑과 같은 따뜻한 색으로 보이는 경우가 많습니다. 이는 태양 빛이 대기를 통과하는 거리가 길어지면서 파란색 빛이 더 많이 산란되고, 상대적으로 긴 파장의 빛인 빨간색이나 주황색이 더 많이 우리 눈에 도달하기 때문입니다.

# %%
# 평가 프롬프트 출처: MT-Bench 논문 https://arxiv.org/pdf/2306.05685.pdf (A. Prompt Templates Figure 5)

prompt = f"""[System]
Please act as an impartial judge and evaluate the quality of the responses provided by two
AI assistants to the user question displayed below. You should choose the assistant that
follows the user’s instructions and answers the user’s question better. Your evaluation
should consider factors such as the helpfulness, relevance, accuracy, depth, creativity,
and level of detail of their responses. Begin your evaluation by comparing the two
responses and provide a short explanation. Avoid any position biases and ensure that the
order in which the responses were presented does not influence your decision. Do not allow
the length of the responses to influence your evaluation. Do not favor certain names of
the assistants. Be as objective as possible. After providing your explanation, output your
final verdict by strictly following this format: "[[A]]" if assistant A is better, "[[B]]"
if assistant B is better, and "[[C]]" for a tie.

[User Question]
{question}

[The Start of Assistant A’s Answer]
{answer_a}
[The End of Assistant A’s Answer]

[The Start of Assistant B’s Answer]
{answer_b}
[The End of Assistant B’s Answer]"""

print(prompt)
# Out:
# [System]
# Please act as an impartial judge and evaluate the quality of the responses provided by two
# AI assistants to the user question displayed below. You should choose the assistant that
# follows the user’s instructions and answers the user’s question better. Your evaluation
# should consider factors such as the helpfulness, relevance, accuracy, depth, creativity,
# and level of detail of their responses. Begin your evaluation by comparing the two
# responses and provide a short explanation. Avoid any position biases and ensure that the
# order in which the responses were presented does not influence your decision. Do not allow
# the length of the responses to influence your evaluation. Do not favor certain names of
# the assistants. Be as objective as possible. After providing your explanation, output your
# final verdict by strictly following this format: "[[A]]" if assistant A is better, "[[B]]"
# if assistant B is better, and "[[C]]" for a tie.
#
# [User Question]
# ...

# %%
completion = client.chat.completions.create(
    model='gpt-4o',
    messages=[{'role': 'user', 'content': prompt}],
    temperature=0.0
)

print(completion.choices[0].message.content)
# Out:
# Assistant A provides a concise explanation of why the sky appears blue, focusing on the interaction between sunlight and air molecules, and the selective scattering of blue light. However, the explanation lacks depth and does not mention the specific scientific phenomenon responsible for this effect.
#
# Assistant B offers a more detailed and scientifically accurate explanation. It introduces the concept of Rayleigh scattering, explains why shorter wavelengths like blue and violet are scattered more, and addresses why we perceive the sky as blue rather than violet. Additionally, Assistant B includes information about the appearance of the sky during sunrise and sunset, providing a more comprehensive understanding of the phenomenon.
#
# Overall, Assistant B's response is more informative, accurate, and detailed, making it the better answer.
#
# [[B]]

# %% [markdown]
# ## 실제 테스트

# %%
question_test1 = '업로드한 사업 공고문의 핵심 내용을 json 포맷으로 구성해줘. key만 영어로 값은 한국어로 작성해줘.'

print(question_test1)
# Out:
# 사업 공고문의 핵심 내용을 json 포맷으로 구성해줘. key만 영어로 값은 한국어로 작성해줘.

# %%
question_test2 = '업로드한 파일의 핵심 내용을 json 포맷으로 구성해줘. key만 영어로 하고 value는 한글로 작성해줘.'

print(question_test2)

# %%
answer_gpt4o_mini_test1 = """{
  "business_name": "2022년도 중소기업 Net-Zero 기술혁신개발사업 지정공모과제",
  "announcement_number": "중소벤처기업부 공고 제2022–351호",
  "purpose": "저탄소 신산업 분야 중소·벤처기업과 연구기관의 공동 기술개발을 지원하여 탄소중립 기술경쟁력 확보",
  "support_scale": {
    "amount": "30억원",
    "number_of_projects": 8,
    "support_period": "최대 3년",
    "support_limit": "최대 10억원/12개월",
    "government_support_ratio": "80% 이내"
  },
  "eligible_applicants": [
    "중소기업을 주관연구개발기관으로 하고, 연구기관을 공동연구개발기관으로 하는 2개 이상의 기관으로 구성된 컨소시엄"
  ],
  "support_type": "지정공모",
  "support_fields": [
    "탄소중립 기술혁신 10대 핵심기술 분야",
    "온실가스 감축기술"
  ],
  "announcement_period": {
    "start": "2022-05-26",
    "end": "2022-06-27"
  },
  "submission_period": {
    "start": "2022-06-07",
    "end": "2022-06-27 18:00"
  },
  "evaluation_method": {
    "evaluation_procedure": [
      "기술개발 추진",
      "협약체결",
      "토론식 대면평가"
    ],
    "evaluation_criteria": {
      "technical_quality": 30,
      "business_viability": 20,
      "technical_ability": 20,
      "impact": 15,
      "self_execution_plan": 5,
      "policy_alignment": 10
    },
    "total_score": 100
  },
  "required_documents": [
    "중소기업 기술개발지원 연구개발계획서",
    "신용상태 조회동의서",
    "중소기업기술개발사업 청렴서약서",
    "개인정보 이용 동의서",
    "온실가스 감축량 계산표"
  ],
  "contact_info": {
    "business_overview": {
      "organization": "중소벤처기업부 (기술정책과)",
      "phone": "1357"
    },
    "specialized_agency": {
      "organization": "중소기업기술정보진흥원 (기업협력사업실)",
      "phone": "044-300-0657"
    },
    "submission_system_inquiries": {
      "phone": "1877-2041"
    }
  }
}"""

print(answer_gpt4o_mini_test1)
# Out:
# {
#   "business_name": "2022년도 중소기업 Net-Zero 기술혁신개발사업 지정공모과제",
#   "announcement_number": "중소벤처기업부 공고 제2022–351호",
#   "purpose": "저탄소 신산업 분야 중소·벤처기업과 연구기관의 공동 기술개발을 지원하여 탄소중립 기술경쟁력 확보",
#   "support_scale": {
#     "amount": "30억원",
#     "number_of_projects": 8,
#     "support_period": "최대 3년",
#     "support_limit": "최대 10억원/12개월",
#     "government_support_ratio": "80% 이내"
#   },
#   "eligible_applicants": [
#     "중소기업을 주관연구개발기관으로 하고, 연구기관을 공동연구개발기관으로 하는 2개 이상의 기관으로 구성된 컨소시엄"
#   ],
#   "support_type": "지정공모",
#   "support_fields": [
#     "탄소중립 기술혁신 10대 핵심기술 분야",
#     "온실가스 감축기술"
#   ],
#   "announcement_period": {
#     "start": "2022-05-26",
#     "end": "2022-06-27"
#   },
#   "submission_period": {
#     "start": "2022-06-07",
#     "end": "2022-06-27 18:00"
#   },
#   "evaluation_method": {
#     "evaluation_procedure": [
#       "기술개발 추진",
#       "협약체결",
#       "토론식 대면평가"
#     ],
#     "evaluation_criteria": {
#       "technical_quality": 30,
# ...

# %%
answer_gpt4o_mini_test2 = """{
  "announcement_title": "2022년도 중소기업 Net-Zero 기술혁신개발사업 지정공모과제 시행계획 공고",
  "department": "중소벤처기업부",
  "date_of_announcement": "2022년 5월 26일",
  "project_purpose": "저탄소 신산업 분야 중소기업과 연구기관의 공동 기술개발 지원을 통해 중소기업의 탄소중립 기술경쟁력 확보",
  "funding_size": "30억원, 8개 과제",
  "funding_type": "지정공모",
  "funding_areas": [
    "저탄소 신유망 중소기업 육성",
    "탄소중립 기술혁신 10대 핵심기술 분야"
  ],
  "target_organizations": [
    "중소기업(주관연구개발기관)",
    "연구기관(공동연구개발기관)"
  ],
  "support_details": {
    "project_duration": "최대 3년",
    "funding_limit": "30억원 이내 (최대 10억원/12개월)",
    "government_support_ratio": "80% 이내"
  },
  "application_period": {
    "announcement_period": "2022. 5. 26. ~ 2022. 6. 27.",
    "online_submission_period": "2022. 6. 7. ~ 2022. 6. 27. 18:00까지"
  },
  "evaluation_criteria": {
    "technology_score": 30,
    "business_score": 20,
    "technology_development_score": 20,
    "effect_score": 15,
    "self_execution_score": 5,
    "policy_alignment_score": 10
  },
  "evaluation_procedure": "연구개발계획서 제출 후 토론식 대면평가 진행",
  "application_method": "범부처통합연구지원시스템을 통한 연구개발계획서 온라인 제출",
  "required_documents": [
    "연구개발계획서",
    "신용상태 조회동의서",
    "청렴서약서",
    "개인정보 이용 동의서",
    "기술료 납부 계획서",
    "온실가스 감축량 계산표"
  ],
  "contact_information": {
    "general_inquiries": "중소벤처기업부, 기술정책과",
    "application_inquiries": "중소기업기술정보진흥원, 기업협력사업실",
    "helpline": "1357 (중소기업 통합콜센터)"
  },
  "workshop_details": {
    "date": "2022. 6. 8. 14:00",
    "location": "경기테크노파크 3동 1층 다목적실",
    "online_option": "Zoom을 통한 온라인 설명회"
  }
}"""

# %%
prompt_test = f"""[System]
Please act as an impartial judge and evaluate the quality of the responses provided by two
AI assistants to the user question displayed below. You should choose the assistant that
follows the user’s instructions and answers the user’s question better. Your evaluation
should consider factors such as the helpfulness, relevance, accuracy, depth, creativity,
and level of detail of their responses. Begin your evaluation by comparing the two
responses and provide a short explanation. Avoid any position biases and ensure that the
order in which the responses were presented does not influence your decision. Do not allow
the length of the responses to influence your evaluation. Do not favor certain names of
the assistants. Be as objective as possible. After providing your explanation, output your
final verdict by strictly following this format: "[[A]]" if assistant A is better, "[[B]]"
if assistant B is better, and "[[C]]" for a tie.

Note: '[User A's Question]' corresponds with '[The Start of Assistant A’s Answer]', and '[User B's Question]' corresponds with '[The Start of Assistant B’s Answer]'.

[User A`s Question]
{question_test1}

[User B`s Question]
{question_test2}

[The Start of Assistant A’s Answer]
{answer_gpt4o_mini_test1}
[The End of Assistant A’s Answer]

[The Start of Assistant B’s Answer]
{answer_gpt4o_mini_test2}
[The End of Assistant B’s Answer]"""

print(prompt_test)
# Out:
# [System]
# Please act as an impartial judge and evaluate the quality of the responses provided by two
# AI assistants to the user question displayed below. You should choose the assistant that
# follows the user’s instructions and answers the user’s question better. Your evaluation
# should consider factors such as the helpfulness, relevance, accuracy, depth, creativity,
# and level of detail of their responses. Begin your evaluation by comparing the two
# responses and provide a short explanation. Avoid any position biases and ensure that the
# order in which the responses were presented does not influence your decision. Do not allow
# the length of the responses to influence your evaluation. Do not favor certain names of
# the assistants. Be as objective as possible. After providing your explanation, output your
# final verdict by strictly following this format: "[[A]]" if assistant A is better, "[[B]]"
# if assistant B is better, and "[[C]]" for a tie.
#
# [User Question]
# ...

# %%
# 역할 부여 : 넌 이제 프롬프트를 평가하는 모델이다. 공정하고 객관적으로 평가해줘.
# 파일 업로드 : 해당 공고문

question_test1 = '업로드한 사업 공고문의 핵심 내용을 json 포맷으로 구성해줘. key만 영어로 값은 한국어로 작성해줘.'

question_test2 = '업로드한 파일의 핵심 내용을 json 포맷으로 구성해줘. key만 영어로 하고 value는 한글로 작성해줘.'

answer_gpt4o_mini_test1 = """{
  "business_name": "2022년도 중소기업 Net-Zero 기술혁신개발사업 지정공모과제",
  "announcement_number": "중소벤처기업부 공고 제2022–351호",
  "purpose": "저탄소 신산업 분야 중소·벤처기업과 연구기관의 공동 기술개발을 지원하여 탄소중립 기술경쟁력 확보",
  "support_scale": {
    "amount": "30억원",
    "number_of_projects": 8,
    "support_period": "최대 3년",
    "support_limit": "최대 10억원/12개월",
    "government_support_ratio": "80% 이내"
  },
  "eligible_applicants": [
    "중소기업을 주관연구개발기관으로 하고, 연구기관을 공동연구개발기관으로 하는 2개 이상의 기관으로 구성된 컨소시엄"
  ],
  "support_type": "지정공모",
  "support_fields": [
    "탄소중립 기술혁신 10대 핵심기술 분야",
    "온실가스 감축기술"
  ],
  "announcement_period": {
    "start": "2022-05-26",
    "end": "2022-06-27"
  },
  "submission_period": {
    "start": "2022-06-07",
    "end": "2022-06-27 18:00"
  },
  "evaluation_method": {
    "evaluation_procedure": [
      "기술개발 추진",
      "협약체결",
      "토론식 대면평가"
    ],
    "evaluation_criteria": {
      "technical_quality": 30,
      "business_viability": 20,
      "technical_ability": 20,
      "impact": 15,
      "self_execution_plan": 5,
      "policy_alignment": 10
    },
    "total_score": 100
  },
  "required_documents": [
    "중소기업 기술개발지원 연구개발계획서",
    "신용상태 조회동의서",
    "중소기업기술개발사업 청렴서약서",
    "개인정보 이용 동의서",
    "온실가스 감축량 계산표"
  ],
  "contact_info": {
    "business_overview": {
      "organization": "중소벤처기업부 (기술정책과)",
      "phone": "1357"
    },
    "specialized_agency": {
      "organization": "중소기업기술정보진흥원 (기업협력사업실)",
      "phone": "044-300-0657"
    },
    "submission_system_inquiries": {
      "phone": "1877-2041"
    }
  }
}"""

answer_gpt4o_mini_test2 = """{
  "announcement_title": "2022년도 중소기업 Net-Zero 기술혁신개발사업 지정공모과제 시행계획 공고",
  "department": "중소벤처기업부",
  "date_of_announcement": "2022년 5월 26일",
  "project_purpose": "저탄소 신산업 분야 중소기업과 연구기관의 공동 기술개발 지원을 통해 중소기업의 탄소중립 기술경쟁력 확보",
  "funding_size": "30억원, 8개 과제",
  "funding_type": "지정공모",
  "funding_areas": [
    "저탄소 신유망 중소기업 육성",
    "탄소중립 기술혁신 10대 핵심기술 분야"
  ],
  "target_organizations": [
    "중소기업(주관연구개발기관)",
    "연구기관(공동연구개발기관)"
  ],
  "support_details": {
    "project_duration": "최대 3년",
    "funding_limit": "30억원 이내 (최대 10억원/12개월)",
    "government_support_ratio": "80% 이내"
  },
  "application_period": {
    "announcement_period": "2022. 5. 26. ~ 2022. 6. 27.",
    "online_submission_period": "2022. 6. 7. ~ 2022. 6. 27. 18:00까지"
  },
  "evaluation_criteria": {
    "technology_score": 30,
    "business_score": 20,
    "technology_development_score": 20,
    "effect_score": 15,
    "self_execution_score": 5,
    "policy_alignment_score": 10
  },
  "evaluation_procedure": "연구개발계획서 제출 후 토론식 대면평가 진행",
  "application_method": "범부처통합연구지원시스템을 통한 연구개발계획서 온라인 제출",
  "required_documents": [
    "연구개발계획서",
    "신용상태 조회동의서",
    "청렴서약서",
    "개인정보 이용 동의서",
    "기술료 납부 계획서",
    "온실가스 감축량 계산표"
  ],
  "contact_information": {
    "general_inquiries": "중소벤처기업부, 기술정책과",
    "application_inquiries": "중소기업기술정보진흥원, 기업협력사업실",
    "helpline": "1357 (중소기업 통합콜센터)"
  },
  "workshop_details": {
    "date": "2022. 6. 8. 14:00",
    "location": "경기테크노파크 3동 1층 다목적실",
    "online_option": "Zoom을 통한 온라인 설명회"
  }
}"""

prompt_test = f"""[System]
Please act as an impartial judge and evaluate the quality of the responses provided by two
AI assistants to the user question displayed below. You should choose the assistant that
follows the user’s instructions and answers the user’s question better. Your evaluation
should consider factors such as the helpfulness, relevance, accuracy, depth, creativity,
and level of detail of their responses. Begin your evaluation by comparing the two
responses and provide a short explanation. Avoid any position biases and ensure that the
order in which the responses were presented does not influence your decision. Do not allow
the length of the responses to influence your evaluation. Do not favor certain names of
the assistants. Be as objective as possible. After providing your explanation, output your
final verdict by strictly following this format: "[[A]]" if assistant A is better, "[[B]]"
if assistant B is better, and "[[C]]" for a tie.

Note: '[User A's Question]' corresponds with '[The Start of Assistant A’s Answer]', and '[User B's Question]' corresponds with '[The Start of Assistant B’s Answer]'.

[User A`s Question]
{question_test1}

[User B`s Question]
{question_test2}

[The Start of Assistant A’s Answer]
{answer_gpt4o_mini_test1}
[The End of Assistant A’s Answer]

[The Start of Assistant B’s Answer]
{answer_gpt4o_mini_test2}
[The End of Assistant B’s Answer]"""

# %%
# prompt_test = f"""[System]
# Please act as an impartial judge and evaluate the quality of the response provided by an 
# AI assistant to the user question displayed below. Your evaluation should consider factors 
# such as the helpfulness, relevance, accuracy, depth, creativity, and level of detail of the 
# response. Begin your evaluation by providing a short explanation. Be as objective as 
# possible. After providing your explanation, please rate the response on a scale of 1 to 10 
# by strictly following this format: "[[rating]]", for example: "Rating: [[5]]".

# [Question]
# {question_test}

# [The Start of Assistant’s Answer]
# {answer_test}
# [The End of Assistant’s Answer]"""

# print(prompt_test)
